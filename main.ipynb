# %%
from kmeans import Kmeans
from utils import load_from_numpy, load_mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
X, Y = load_mnist()
K = 15
epochs = 100
model = Kmeans(X, K, epochs)
model.fit()
# Out:
# 0 / 100
# 1 / 100
# 2 / 100
# 3 / 100
# 4 / 100
# 5 / 100
# 6 / 100
# 7 / 100
# 8 / 100
# 9 / 100
# 10 / 100
# 11 / 100
# 12 / 100
# 13 / 100
# 14 / 100
# 15 / 100
# 16 / 100
# 17 / 100
# 18 / 100
# 19 / 100
# 20 / 100
# 21 / 100
# 22 / 100
# 23 / 100
# 24 / 100
# 25 / 100
# 26 / 100
# 27 / 100
# 28 / 100
# 29 / 100
# 30 / 100
# 31 / 100
# 32 / 100
# 33 / 100
# 34 / 100
# 35 / 100
# 36 / 100
# 37 / 100
# 38 / 100
# 39 / 100
# 40 / 100
# 41 / 100
# 42 / 100
# 43 / 100
# 44 / 100
# 45 / 100
# 46 / 100
# 47 / 100
# 48 / 100
# 49 / 100
# 50 / 100
# 51 / 100
# 52 / 100
# 53 / 100
# 54 / 100
# 55 / 100
# 56 / 100
# 57 / 100
# 58 / 100
# 59 / 100
# 60 / 100
# 61 / 100
# 62 / 100
# 63 / 100
# 64 / 100
# 65 / 100
# 66 / 100
# 67 / 100
# 68 / 100
# 69 / 100
# 70 / 100
# 71 / 100
# 72 / 100
# 73 / 100
# 74 / 100
# 75 / 100
# 76 / 100
# 77 / 100
# 78 / 100
# 79 / 100
# 80 / 100
# 81 / 100
# 82 / 100
# 83 / 100
# 84 / 100
# 85 / 100
# 86 / 100
# 87 / 100
# 88 / 100

# %%
encoded = model.encode(X[0])
print(encoded)
# Out:
# 2

# %%
decoded = model.decode(encoded)

# %%
images = [np.reshape(decoded, (28, 28)), np.reshape(X[0], (28, 28))]
plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
# Out:
# <ipython-input-5-8e1bcbba5353>:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(len(images) / columns + 1, columns, i + 1)

# %%
encoded_l = []
for x in X:
    encoded_l.append(model.encode(x))

# %%
from collections import Counter
import collections
encoded_dic = {}

for i in range(len(Y)):
    if encoded_l[i] not in encoded_dic:
        encoded_dic[encoded_l[i]] = []
    encoded_dic[encoded_l[i]].append(Y[i])
    

l = []
for i in range(10):
    d = dict(Counter(encoded_dic[i]))
    od = collections.OrderedDict(sorted(d.items()))
    l.append(od)

for i, D in enumerate(l):
    plt.title(f"{i}")
    plt.bar(range(len(D)), list(D.values()), align='center')
    plt.xticks(range(len(D)), list(D.keys()))
    plt.show()

# %%
decoded_list = []
for i in range(K):
    decoded_list.append(model.decode(i))
    
images = [np.reshape(decoded, (28, 28)) for decoded in decoded_list] 
plt.figure(figsize=(20,10))
columns = 10
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
# Out:
# <ipython-input-13-553717c913e7>:9: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(len(images) / columns + 1, columns, i + 1)
